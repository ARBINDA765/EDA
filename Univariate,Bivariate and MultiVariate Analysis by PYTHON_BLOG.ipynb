# %% [markdown]
# # Data science life cycle:
# Every Data science Beginner, working professional, student or practitioner follows a few steps while doing. I will tell you about all these steps in simple terms for your understanding.

# %% [markdown]
# # 1.Hypothesis definition:- A proposed explanation as a starting point for further investigation.
# Ex:- A(company) wants to release a Raincoat(product) in Summer. now the company is in a dilemma whether to release the product or not. (i know its a bad idea, but for understanding, let's think this.)

# %% [markdown]
# # 2. Data Acquisition:- collecting the required data.
# Ex:- collecting the last 10 years of data in a certain region.

# %% [markdown]
# # 3.Exploratory Data Analysis(EDA):-
#     Analysing collected data using some concepts(will see them below).
# Ex: on collected data(existing data)data scientists will perform some analysis and decide, what are features/metrics to consider for model building.

# %% [markdown]
# # 4.Model building:-
# This is where Machine learning comes into light.
# #Ex:- by using metrics(outputs of EDA), they will predict(using ML )whether the product will be successful or not if it goes into the market.

# %% [markdown]
# # 5.Result report:-
# After doing EDA and Model building, it generates results.
# Ex: as a result of all the above steps we get some results, which decides whether to start production or not

# %% [markdown]
# # 6.final Product:-
# Based on the result, we will get a product.
# Ex:- if the result generated is positive, A(company) can start production. if the result is negative, A won't start production.

# %% [markdown]
# # Exploratory Data Analysis:-
# By definition, exploratory data analysis is an approach to analysing data to summarise their main characteristics, often with visual methods.
# in other words, we perform analysis on data that we collected, to find important metrics/features by using some nice and pretty visualisations.
# every person takes some decisions in their life considering a few points in some situations. to be accurate at these decisions data scientist does some EDA on data.
#
# # Exploratory Data Analysis is majorly performed using the following methods:

# %% [markdown]
# # Univariate analysis:-
#  Univariate analysis provides summary statistics for each field in the raw data set (or) summary only on one variable. Ex:- CDF,PDF,Box plot, Violin plot.(don't worry, will see below what each of them is)

# %% [markdown]
# # Bivariate analysis:-
# Bivariate analysis is performed to find the relationship between each variable in the dataset and the target variable of interest (or) using 2 variables and finding the relationship between them.Ex:-Box plot, Violin plot.

# %% [markdown]
# # Multivariate analysis:-
# Multivariate analysis is performed to understand interactions between different fields in the dataset (or) finding interactions between variables more than 2. Ex:- Pair plot and 3D scatter plot.

# %% [markdown]
# #let's download a data set from Kaggle(home for Data scientists), you can download and know more about it here →Habberman dataset.
# https://www.kaggle.com/gilsousa/habermans-survival-data-set

# %%
#IMPORTING LIBRARY
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Reading the dataset
Cancer_sur=pd.read_csv('haberman.csv')

# %%
#Reading the top 5 lines of the dataframe
Cancer_sur.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %% [raw]
# #if you look at it, you can see top 5 rows, but not able to make sense, because there are no column labels to it.
# #let's add columns to it

# %%
#if you look at it, you can see top 5 rows, but not able to make sense, because there are no column labels to it.
#let's add columns to it
Cancer_sur=pd.read_csv('haberman.csv',header=None,names=[ "Age", "Operation_year", "axil_nodes_det", "Surv_status"])

# %%
#lets see first 5 rows 
Cancer_sur.head()
# Out:
#    Age  Operation_year  axil_nodes_det  Surv_status
# 0   30              64               1            1
# 1   30              62               3            1
# 2   30              65               0            1
# 3   31              59               2            1
# 4   31              65               4            1

# %%
#lets see last 5 rows using Cancer_sur.tail().
Cancer_sur.tail()
# Out:
#      Age  Operation_year  axil_nodes_det  Surv_status
# 301   75              62               1            1
# 302   76              67               0            1
# 303   77              65               3            1
# 304   78              65               1            2
# 305   83              58               2            2

# %%
#High level statistics:
print(Cancer_sur.info())
print("*"* 90)
print(Cancer_sur.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             306 non-null    int64
#  1   Operation_year  306 non-null    int64
#  2   axil_nodes_det  306 non-null    int64
#  3   Surv_status     306 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB
# None
# ******************************************************************************************
#               Age  Operation_year  axil_nodes_det  Surv_status
# count  306.000000      306.000000      306.000000   306.000000
# mean    52.457516       62.852941        4.026144     1.264706
# std     10.803452        3.249405        7.189654     0.441899
# min     30.000000       58.000000        0.000000     1.000000
# 25%     44.000000       60.000000        0.000000     1.000000
# 50%     52.000000       63.000000        1.000000     1.000000
# ...

# %% [markdown]
# # Observation:
# It has 306 rows & 4 columns(Feature)
# Minimum age is 30 & Maximum age is 83 along with mean age of 52 & having the standard deviation of 10.83
# Maximum Year is 1969 & Minimum year is 1962
# 75% Patient is having axil_nodes =4 & 25% of patient have "0" axil_node

# %%
#shape gives no of rows and columns.
Cancer_sur.shape
# Out:
# (306, 4)

# %%
#Surv_status is a target column (Dependent feature)
Cancer_sur['Surv_status'].value_counts()
#Surv_status is a target column where it gives 2 values 1(means survived) and 2(not survived). 
# we have observed that 225 rows(people) with value 1(survived) and 81rows(people) with value 2(not survived).
# Out:
# 1    225
# 2     81
# Name: Surv_status, dtype: int64

# %% [markdown]
# # Univariate analysis(PDF, CDF, Boxplot, Violin plots,Distribution plots):

# %%
#Distribution plots
sns.FacetGrid(Cancer_sur,hue="Surv_status",height=6).map(sns.histplot,"Age").add_legend()
# value 1(survived)
#value 2(not survived).
#People Age in between 50 to 60 are having more survived

# %%
#now let's draw the same with another column “Operation_year”
sns.FacetGrid(Cancer_sur,hue="Surv_status",height=6).map(sns.histplot,"Operation_year").add_legend()
#we can say that people who had an operation in the year from 58 to 66 had more survival rate.

# %% [markdown]
# # CDF(cumulative distributive function), PDF(probability density function):

# %%
counts,bin_edges = np.histogram(Cancer_sur['Age'],bins=10,density=True)
plt.xlabel('Age')
pdf=counts/(sum(counts))
print("COUNTS:",counts)
print("BIN_EDGES:",bin_edges)
print("probability density function:",pdf)
cdf=np.cumsum(pdf)
print("cumulative distributive function:",cdf)
#pdf=RED COLOR
plt.plot(bin_edges[1:],pdf,color="red")
#CDF=GREEN
plt.plot(bin_edges[1:],cdf,color="green")
# Out:
# COUNTS: [0.00986558 0.01664817 0.02836355 0.03267974 0.03391294 0.02528055
#  0.02528055 0.01109878 0.00431619 0.0012332 ]
# BIN_EDGES: [30.  35.3 40.6 45.9 51.2 56.5 61.8 67.1 72.4 77.7 83. ]
# probability density function: [0.05228758 0.08823529 0.1503268  0.17320261 0.17973856 0.13398693
#  0.13398693 0.05882353 0.02287582 0.00653595]
# cumulative distributive function: [0.05228758 0.14052288 0.29084967 0.46405229 0.64379085 0.77777778
#  0.91176471 0.97058824 0.99346405 1.        ]

# %% [markdown]
# # Observation from PDF & CDF

# %% [markdown]
# ''' It has been observed that BY probability density function what percentage of tOtal distribution of data  (Used dataset) will fall in
# x Axis.if we will  combine all it will be total 1(100%),can not be go beyound of 100%.
#
#
# #By CDF(cumulative distributive function) we can say that if we draw a straight line from Age value at 60, then it intersects the curve Cumulative distribution function(green) at a value approximately equal to 0.6 .
# i.e there are 60% of distribution of  Age in between  30 to 60 age. (OR less than Age of 60)'''

# %% [markdown]
# # Bivariate analysis:
# It will  give the relationship between the two variables, hence its called bivariate analysis.

# %% [markdown]
# # BOX PLOT:
# Box plot is a nice way of viewing some statical values along with relationship between two values.

# %%
#Box Plot between Age & surv_status
# graphs that are in blue shows 1=(survived) and yellow with 2=(not survived).
sns.boxplot(x="Surv_status",y="Age",data=Cancer_sur)
#it is observed that people that had the operation in the year 1958 to 1966 survived.
# Out:
# <AxesSubplot:xlabel='Surv_status', ylabel='Age'>

# %%
#Box plot between Surv_Status and Operation year.
sns.boxplot(x="Surv_status",y="Operation_year",data=Cancer_sur)
#it is observed that people that had the operation in the year 1958 to 1966 survived.
# Out:
# <AxesSubplot:xlabel='Surv_status', ylabel='Operation_year'>

# %% [markdown]
# # Violin plot:
# violin plots also like box plots, but these give pdf along with box plots in it. they look a violin.

# %%
sns.violinplot(x='Surv_status',y='Operation_year',data=Cancer_sur,size=60)
#We  can observe that people with operation year from 58 to 66 survived more as after that the graphs decreased as
#you can see in the below figure.
# Out:
# <AxesSubplot:xlabel='Surv_status', ylabel='Operation_year'>

# %% [markdown]
# # Multivariate Analysis:

# %%
color = ["green", "White", "Red", "Yellow", "Green", "Grey"]
sns.set_palette(color)
sns.palplot(sns.color_palette())

# %%
sns.pairplot(hue="Surv_status",data=Cancer_sur,height=3.5)
plt.show()
